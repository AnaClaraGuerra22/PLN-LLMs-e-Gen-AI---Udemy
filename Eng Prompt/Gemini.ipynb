# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyCQAkh1PfqlVtHsS5O9FnTvzD13V1XF-PE")
model = genai.GenerativeModel("gemini-1.5-pro")

# %%
response = model.generate_content(
    "Crie uma receita de sobremesa baseada no tema 'futuro'.",
    generation_config=genai.types.GenerationConfig(
        candidate_count=1,
        #stop_sequences=["pronto"],
        max_output_tokens=300,
        temperature=1.5,
        top_p=0.7,
        top_k=5,
        presence_penalty=0.0,
        frequency_penalty=0.0,
    ),
)
print(response.text)
# Out:
# ## Esferas de Névoa Cósmica com Geleia de Singularidade
#
# **Uma sobremesa futurista com textura inovadora e sabores surpreendentes.**
#
# **Rendimento:** 4 porções
# **Tempo de preparo:** 45 minutos + 2 horas de refrigeração
# **Dificuldade:** Média
#
# **Ingredientes:**
#
# **Para as Esferas de Névoa Cósmica:**
#
# * 200ml de leite de coco integral (bem gelado)
# * 100g de açúcar demerara
# * 5g de ágar-ágar em pó
# * Corante alimentício azul e roxo (em gel ou líquido)
# * Nitrogênio líquido (opcional, para efeito de fumaça)
#
# **Para a Geleia de Singularidade:**
#
# * 200g de mirtilos frescos
# * 50g de açúcar
# * 2 colheres de sopa de suco de limão
# * 1 pitada de gengibre em pó
# * Estrelas comestíveis prateadas (opcional)
#
# **Equipamentos:**
#
# * Liquidificador
# * Bacia com água gelada
# * Seringa culinária ou conta-gotas
# * Tigelas pequenas
# * Panela pequena
#
#
# **Preparo:**
#
# **Esferas de Névoa Cósmica:**
#
# 1. Em uma panela pequena, misture o leite de coco, o açúcar e o ágar-ágar.
# 2.
